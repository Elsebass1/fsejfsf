# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def s(x):
  return -1.6*x**2+1.3*x+141.3
def r(x):
  return 1.4*x**2-5.6*x+12.6
#Definiendo la función igualada a cero intersección para funciones g(x) y r(x) previamente definidas
def inter(x):
  return s(x)-r(x)

x = np.linspace(0, 15, 15)

#np.around() permite redondear los valores a 2 decimales y elimina los restantes
solucion = np.around(fsolve(inter, x), decimals = 2)

#np.unique() permite eliminar las soluciones repetidas
interseccion = np.unique(solucion)

print(f'Los puntos de intersección de las funciones están en x = {interseccion}')
# Out:
# Los puntos de intersección de las funciones están en x = [-5.5  7.8]

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# porque el dominio es el minimo de 0 campañas o maximo de 15

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# La respuesta es 8

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
  return 50*np.exp(0.3*x) - 551

#Valor/es inicial/es de la aproximación
xo = np.linspace(0,600,1)
solucion = fsolve(f, xo)
print(solucion)
# Out:
# [7.99903935]

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# La respuesta correcta es la C 302.5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
  return 50*np.exp(0.3*x)
print(f(6))
# Out:
# 302.4823732206472

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# la correcta es la A 650

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
def f(x):
  return x**3-4*x**2+5*x
print(f(10))
# Out:
# 650

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Respuesta correcta 26

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve


def f(x):
    return 50*x+200 - 1500

xo = np.linspace(0,1600,1)
solucion = fsolve(f, xo)
print(solucion)
# Out:
# [26.]

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Respuesta correcta es 1200

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
    return 50*x+200
print(f(20))
# Out:
# 1200

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
  return 1-2*x
x = np.arange(0,200,0.1)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# La respuesta es 15

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
  return 2*x**2 + 3*x + 5 - 500

xo = np.linspace(0,600,1)
solucion = fsolve(f, xo)
print(solucion)
# Out:
# [15.]

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
  return 2*x**2 + 3*x + 5
print(f(50))
# Out:
# 5155

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# La respuesta correcta es de 6 a 20

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

x = np.array([5,10])
y = np.array([50,80])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)
print(pendiente, intercepto)
# Out:
# 6.000000000000001 19.999999999999986

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)
